# %%
from rdflib import Graph, Namespace, RDF, FOAF
from rdflib import Graph, URIRef, Literal, BNode


ZZ = Namespace("ontology.owl")
# print(dir(ZZ))

# # Create a Graph
g = Graph()
g.parse("ontology.owl")

# # Parse in an RDF file hosted on the Internet
g.bind("zz", ZZ)
bob = URIRef("http://example.org/people/Bob")
linda = BNode()  # a GUID is generated


g.add((bob, FOAF.knows, linda))
g.add((linda, RDF.type, ZZ.Player))
g.add((linda, ZZ.player, Literal("Linda")))

print(g.serialize())



# # Loop through each triple in the graph (subj, pred, obj)
# for subj, pred, obj in g:
#     # Check if there is at least one triple in the Graph
#     if (subj, pred, obj) not in g:
#        raise Exception("It better be!")

# # Print the number of "triples" in the Graph
# print(f"Graph g has {len(g)} statements.")
# # Prints: Graph g has 86 statements.

# # Print out the entire Graph in the RDF Turtle format
# print(g.serialize(format="turtle"))
# Out:
# @prefix : <http://www.semanticweb.org/miguel/ontologies/2022/10/FootyPedia#> .
# @prefix ns1: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://example.org/people/Bob> ns1:knows [ a <ontology.owlPlayer> ;
#             <ontology.owlplayernamasdasdsae> "Linda" ] .
#
# <http://www.semanticweb.org/miguel/ontologies/2022/10/FootyPedia> a owl:Ontology ;
#     rdfs:comment "This is an ontology about a Football from the past 6 years"@en .
#
# :clubAddress a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubAssociation a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubCity a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubCountry a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubEmail a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubFoundationYear a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubFullName a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubHasSquad a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain :Club ;
#     rdfs:range :Squad ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# :clubImage a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubMainSponsor a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubNickname a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubPresident a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubSponsor a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubUefaRanking a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:range xsd:int ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubWebsite a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :clubWonCompetition a owl:ObjectProperty ;
#     rdfs:domain :Club ;
#     rdfs:range :Competition .
#
# :clubZeroZeroLink a owl:DatatypeProperty ;
#     rdfs:domain :Club ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :editionOfLeague a owl:FunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain :Edition ;
#     rdfs:range :League ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# :playerPlayedForSquad a owl:ObjectProperty ;
#     rdfs:domain :Player ;
#     rdfs:range :Squad ;
#     rdfs:subPropertyOf owl:topObjectProperty ;
#     owl:propertyChainAxiom ( :playerHasRecord :recordForSuqad ) .
#
# :playerWonCompetition a owl:ObjectProperty ;
#     rdfs:domain :Player ;
#     rdfs:range :Competition ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# :playerage a owl:DatatypeProperty ;
#     rdfs:domain :Player ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :playerbirthdate a owl:DatatypeProperty ;
#     rdfs:domain :Player ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :playerbirthplace a owl:DatatypeProperty ;
#     rdfs:domain :Player ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :playerfoot a owl:DatatypeProperty ;
#     rdfs:domain :Player ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :playerheight a owl:DatatypeProperty ;
#     rdfs:domain :Player ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :playerimage a owl:DatatypeProperty ;
#     rdfs:domain :Player ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :playername a owl:DatatypeProperty ;
#     rdfs:domain :Player ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :playernationality a owl:DatatypeProperty ;
#     rdfs:domain :Player ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :playernaturalFrom a owl:DatatypeProperty ;
#     rdfs:domain :Player ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :playerposition a owl:DatatypeProperty ;
#     rdfs:domain :Player ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :playerweight a owl:DatatypeProperty ;
#     rdfs:domain :Player ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :recordassists a owl:DatatypeProperty ;
#     rdfs:domain :Record ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :recordgames a owl:DatatypeProperty ;
#     rdfs:domain :Record ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :recordgoals a owl:DatatypeProperty ;
#     rdfs:domain :Record ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :recordgoalsConceded a owl:DatatypeProperty ;
#     rdfs:domain :Record ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :squadParticipatedIn a owl:FunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain :Squad ;
#     rdfs:range :Edition ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# :League a owl:Class .
#
# :playerHasRecord a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain :Player ;
#     rdfs:range :Record ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# :recordForSuqad a owl:FunctionalProperty,
#         owl:ObjectProperty,
#         owl:TransitiveProperty ;
#     rdfs:domain :Record ;
#     rdfs:range :Squad ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# :Competition a owl:Class .
#
# :Edition a owl:Class .
#
# :Squad a owl:Class .
#
# :Record a owl:Class .
#
# :Player a owl:Class .
#
# :Club a owl:Class .

# %%
from rdflib import Graph

# Create a Graph, pare in Internet data
g = Graph().parse("http://www.w3.org/People/Berners-Lee/card")

# Query the data in g using SPARQL
# This query returns the 'name' of all ``foaf:Person`` instances
q = """
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>

    SELECT ?name
    WHERE {
        # ?p rdf:type foaf:Person .

        # ?p foaf:name ?name .
    }
"""

# Apply the query to the graph and iterate through results
for r in g.query(q):
    print(r["name"])

# prints: Timothy Berners-Lee
# Out:
# Timothy Berners-Lee
